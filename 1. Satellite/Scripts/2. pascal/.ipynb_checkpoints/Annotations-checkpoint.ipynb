# %%
import os

root_path = '../../database/PASCAL_format/Annotations'
new_image_root_path='../../database/PASCAL_format/JPEGImages'

def GetLista(path):  
    global image_root_path
    image_root_path=path
    lista = [f.replace(".json","") for f in os.listdir(image_root_path) if f.endswith(".json")]
    return lista

# %%
import  os
if not os.path.exists(root_path):
    os.makedirs(root_path)

# %%
import os
from lxml import etree

def GenerateFile(filename, xml):
    s = etree.tostring(root, pretty_print=True).decode("utf-8") 
    file_path = os.path.join(root_path, filename)
    if(os.path.isfile(file_path)):
        os.remove(file_path)
    with open(file_path, 'w') as f:
        f.write(s)
    print("file written:", file_path)

# %%
from lxml import etree
import json
import numpy as np
from PIL import Image

def GenerateXML(file):
    def GetBoundingBox(_points):
        xmin, ymin, xmax, ymax = np.inf, np.inf, 0, 0
        for _point in _points:
            if(_point[0]<xmin):
                xmin=_point[0]
            if(_point[1]<ymin):
                ymin=_point[1]
            if(_point[0]>xmax):
                xmax=_point[0]
            if(_point[1]>ymax):
                ymax=_point[1]
        return int(np.floor(xmin)), int(np.floor(ymin)), int(np.ceil(xmax)), int(np.ceil(ymax))
    _json_path = os.path.join(image_root_path,file+'.json')
    with open(_json_path, 'r') as f:
        read_data = f.read()
    _data = json.loads(read_data)
    
    root = etree.Element('annotation')
    folder = etree.Element('folder')
    folder.text = 'VOC2012'
    root.append(folder)
    
    filename = etree.Element('filename')
    filename.text = file + '.jpg'
    root.append(filename)
    
    source = etree.Element('source')
    database = etree.Element('database')
    database.text = 'The VOC2007 Database'
    source.append(database)
    annotation = etree.Element('annotation')
    annotation.text = 'PASCAL VOC2007'
    source.append(annotation)
    root.append(source)
    
    _image_path = os.path.join(new_image_root_path,file+'.jpg')
    _im = Image.open(_image_path)
    _width, _height = _im.size
    _width, _height = str(_width), str(_height)
    size = etree.Element('size')
    width = etree.Element('width')
    width.text = _width
    size.append(width)
    height = etree.Element('height')
    height.text = _height
    size.append(height)
    depth = etree.Element('depth')
    depth.text = '3' # TODO
    size.append(depth)
    root.append(size)
    
    segmented = etree.Element('segmented')
    segmented.text = '1'
    root.append(segmented)
    
    for _shape in _data['shapes']:
        objecta = etree.Element('object')
        name = etree.Element('name')
        name.text = 'parkingspot'
        objecta.append(name)
        pose = etree.Element('pose')
        pose.text = 'Frontal'
        objecta.append(pose)
        truncated = etree.Element('truncated')
        truncated.text = '0'
        objecta.append(truncated)
        difficult = etree.Element('difficult')
        difficult.text = '0'
        objecta.append(difficult)

        _xmin, _ymin, _xmax, _ymax = GetBoundingBox(_shape['points'])
        _xmin, _ymin, _xmax, _ymax = str(_xmin), str(_ymin), str(_xmax), str(_ymax)
        
        bndbox = etree.Element('bndbox')
        xmin = etree.Element('xmin')
        xmin.text = _xmin
        bndbox.append(xmin)
        ymin = etree.Element('ymin')
        ymin.text = _ymin
        bndbox.append(ymin)
        xmax = etree.Element('xmax')
        xmax.text = _xmax
        bndbox.append(xmax)
        ymax = etree.Element('ymax')
        ymax.text = _ymax
        bndbox.append(ymax)
        objecta.append(bndbox)

        root.append(objecta)
    
    return root

lista=GetLista("../../database/training")
for f in lista:
    root = GenerateXML(f)
    GenerateFile(f + ".xml", root)

lista=GetLista("../../database/testing")
for f in lista:
    root = GenerateXML(f)
    GenerateFile(f + ".xml", root)
# Out:
# file written: ../../database/PASCAL_format/Annotations\101881731.xml
# file written: ../../database/PASCAL_format/Annotations\104101927.xml
# file written: ../../database/PASCAL_format/Annotations\104357814.xml
# file written: ../../database/PASCAL_format/Annotations\104357815.xml
# file written: ../../database/PASCAL_format/Annotations\104357817.xml
# file written: ../../database/PASCAL_format/Annotations\116016718.xml
# file written: ../../database/PASCAL_format/Annotations\119422707.xml
# file written: ../../database/PASCAL_format/Annotations\119422952.xml
# file written: ../../database/PASCAL_format/Annotations\126381586.xml
# file written: ../../database/PASCAL_format/Annotations\126381588.xml
# file written: ../../database/PASCAL_format/Annotations\126381594.xml
# file written: ../../database/PASCAL_format/Annotations\127649594.xml
# file written: ../../database/PASCAL_format/Annotations\127649606.xml
# file written: ../../database/PASCAL_format/Annotations\130730813.xml
# file written: ../../database/PASCAL_format/Annotations\132613254.xml
# file written: ../../database/PASCAL_format/Annotations\134714700.xml
# file written: ../../database/PASCAL_format/Annotations\134714701.xml
# file written: ../../database/PASCAL_format/Annotations\136128142.xml
# file written: ../../database/PASCAL_format/Annotations\136128143.xml
# file written: ../../database/PASCAL_format/Annotations\137007454.xml
# file written: ../../database/PASCAL_format/Annotations\137007455.xml
# file written: ../../database/PASCAL_format/Annotations\139146552.xml
# file written: ../../database/PASCAL_format/Annotations\139146568.xml
# file written: ../../database/PASCAL_format/Annotations\144848258.xml
# file written: ../../database/PASCAL_format/Annotations\147397541.xml
# file written: ../../database/PASCAL_format/Annotations\148521975.xml
# file written: ../../database/PASCAL_format/Annotations\151179182.xml
# file written: ../../database/PASCAL_format/Annotations\152164339_incomplete.xml
# file written: ../../database/PASCAL_format/Annotations\153028544.xml
# file written: ../../database/PASCAL_format/Annotations\15311494.xml
# file written: ../../database/PASCAL_format/Annotations\154217854.xml
# file written: ../../database/PASCAL_format/Annotations\154221773.xml
# file written: ../../database/PASCAL_format/Annotations\156352855.xml
# file written: ../../database/PASCAL_format/Annotations\156352858.xml
# file written: ../../database/PASCAL_format/Annotations\156352860.xml
# file written: ../../database/PASCAL_format/Annotations\156359105.xml
# file written: ../../database/PASCAL_format/Annotations\156359109.xml
# file written: ../../database/PASCAL_format/Annotations\156359112.xml
# file written: ../../database/PASCAL_format/Annotations\156360956.xml
# file written: ../../database/PASCAL_format/Annotations\156886202.xml
# file written: ../../database/PASCAL_format/Annotations\157756975.xml
# file written: ../../database/PASCAL_format/Annotations\157967280.xml
# file written: ../../database/PASCAL_format/Annotations\158768955.xml
# file written: ../../database/PASCAL_format/Annotations\158974988.xml
# file written: ../../database/PASCAL_format/Annotations\159269575.xml
# file written: ../../database/PASCAL_format/Annotations\159844816.xml
# file written: ../../database/PASCAL_format/Annotations\159860886.xml
# file written: ../../database/PASCAL_format/Annotations\159860891.xml
# file written: ../../database/PASCAL_format/Annotations\162450366.xml
# file written: ../../database/PASCAL_format/Annotations\163314900.xml
# file written: ../../database/PASCAL_format/Annotations\166725206.xml
# file written: ../../database/PASCAL_format/Annotations\166725208.xml
# file written: ../../database/PASCAL_format/Annotations\169474254.xml
# file written: ../../database/PASCAL_format/Annotations\175484438.xml
# file written: ../../database/PASCAL_format/Annotations\175934755.xml
# file written: ../../database/PASCAL_format/Annotations\176329920.xml
# file written: ../../database/PASCAL_format/Annotations\176593348.xml
# file written: ../../database/PASCAL_format/Annotations\176593349.xml
# file written: ../../database/PASCAL_format/Annotations\176593350.xml
# file written: ../../database/PASCAL_format/Annotations\177075398.xml
# file written: ../../database/PASCAL_format/Annotations\179776749.xml
# file written: ../../database/PASCAL_format/Annotations\180332956.xml
# file written: ../../database/PASCAL_format/Annotations\180347405.xml
# file written:
