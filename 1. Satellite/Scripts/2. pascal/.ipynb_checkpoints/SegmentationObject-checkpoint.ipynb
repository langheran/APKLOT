# %%
import os

image_root_path = "../../database/training"
new_image_root_path = "../../database/PASCAL_format/JPEGImages"
root_path = '../../database/PASCAL_format/SegmentationObject'

def GetLista(path):
    global image_root_path
    image_root_path = path
    lista = [f.replace(".json","") for f in os.listdir(image_root_path) if f.endswith(".json")]
    return lista

# %%
import  os
if not os.path.exists(root_path):
    os.makedirs(root_path)

# %%
import os
from lxml import etree
import json
import cv2
import numpy as np

def GenerateFile(file, image_root_path):
    _json_path = os.path.join(image_root_path,file+'.json')
    with open(_json_path, 'r') as f:
        read_data = f.read()
    _data = json.loads(read_data)
    _shapes = [shape["points"] for shape in _data["shapes"] if shape["label"]=="1"]
    
    filename = file + ".png"
    file_path = os.path.join(root_path, filename)
    if(os.path.isfile(file_path)):
        os.remove(file_path)
    
    _image_path = os.path.join(new_image_root_path,file+'.jpg')
    _img = cv2.imread(_image_path, 1)
    
    _mask = np.zeros((_img.shape[0], _img.shape[1]))
    for _shape in _shapes:
        _shape.append(_shape[0])
        _shape = [[int(round(pt[0], 0)), int(round(pt[1], 0))] for pt in _shape]
        _pts=np.array(_shape)
        _roi_pts = _pts.reshape((-1, 1, 2))
        cv2.fillConvexPoly(_mask, _roi_pts, 1)
        
    _mask = _mask.astype(np.bool)  
    out = np.zeros_like(_img)
    out[_mask] = 255
    cv2.imwrite(file_path, out)

    print("file written:", file_path)
    
lista=GetLista("../../database/training")
for f in lista:
    GenerateFile(f, image_root_path)
    
lista=GetLista("../../database/testing")
for f in lista:
    GenerateFile(f, image_root_path)
# Out:
# file written: ../../database/PASCAL_format/SegmentationClass\101881731.png
# file written: ../../database/PASCAL_format/SegmentationClass\104101927.png
# file written: ../../database/PASCAL_format/SegmentationClass\104357814.png
# file written: ../../database/PASCAL_format/SegmentationClass\104357815.png
# file written: ../../database/PASCAL_format/SegmentationClass\104357817.png
# file written: ../../database/PASCAL_format/SegmentationClass\116016718.png
# file written: ../../database/PASCAL_format/SegmentationClass\119422707.png
# file written: ../../database/PASCAL_format/SegmentationClass\119422952.png
# file written: ../../database/PASCAL_format/SegmentationClass\126381586.png
# file written: ../../database/PASCAL_format/SegmentationClass\126381588.png
# file written: ../../database/PASCAL_format/SegmentationClass\126381594.png
# file written: ../../database/PASCAL_format/SegmentationClass\127649594.png
# file written: ../../database/PASCAL_format/SegmentationClass\127649606.png
# file written: ../../database/PASCAL_format/SegmentationClass\130730813.png
# file written: ../../database/PASCAL_format/SegmentationClass\132613254.png
# file written: ../../database/PASCAL_format/SegmentationClass\134714700.png
# file written: ../../database/PASCAL_format/SegmentationClass\134714701.png
# file written: ../../database/PASCAL_format/SegmentationClass\136128142.png
# file written: ../../database/PASCAL_format/SegmentationClass\136128143.png
# file written: ../../database/PASCAL_format/SegmentationClass\137007454.png
# file written: ../../database/PASCAL_format/SegmentationClass\137007455.png
# file written: ../../database/PASCAL_format/SegmentationClass\139146552.png
# file written: ../../database/PASCAL_format/SegmentationClass\139146568.png
# file written: ../../database/PASCAL_format/SegmentationClass\144848258.png
# file written: ../../database/PASCAL_format/SegmentationClass\147397541.png
# file written: ../../database/PASCAL_format/SegmentationClass\148521975.png
# file written: ../../database/PASCAL_format/SegmentationClass\151179182.png
# file written: ../../database/PASCAL_format/SegmentationClass\152164339_incomplete.png
# file written: ../../database/PASCAL_format/SegmentationClass\153028544.png
# file written: ../../database/PASCAL_format/SegmentationClass\15311494.png
# file written: ../../database/PASCAL_format/SegmentationClass\154217854.png
# file written: ../../database/PASCAL_format/SegmentationClass\154221773.png
# file written: ../../database/PASCAL_format/SegmentationClass\156352855.png
# file written: ../../database/PASCAL_format/SegmentationClass\156352858.png
# file written: ../../database/PASCAL_format/SegmentationClass\156352860.png
# file written: ../../database/PASCAL_format/SegmentationClass\156359105.png
# file written: ../../database/PASCAL_format/SegmentationClass\156359109.png
# file written: ../../database/PASCAL_format/SegmentationClass\156359112.png
# file written: ../../database/PASCAL_format/SegmentationClass\156360956.png
# file written: ../../database/PASCAL_format/SegmentationClass\156886202.png
# file written: ../../database/PASCAL_format/SegmentationClass\157756975.png
# file written: ../../database/PASCAL_format/SegmentationClass\157967280.png
# file written: ../../database/PASCAL_format/SegmentationClass\158768955.png
# file written: ../../database/PASCAL_format/SegmentationClass\158974988.png
# file written: ../../database/PASCAL_format/SegmentationClass\159269575.png
# file written: ../../database/PASCAL_format/SegmentationClass\159844816.png
# file written: ../../database/PASCAL_format/SegmentationClass\159860886.png
# file written: ../../database/PASCAL_format/SegmentationClass\159860891.png
# file written: ../../database/PASCAL_format/SegmentationClass\162450366.png
# file written: ../../database/PASCAL_format/SegmentationClass\163314900.png
# file written: ../../database/PASCAL_format/SegmentationClass\166725206.png
# file written: ../../database/PASCAL_format/SegmentationClass\166725208.png
# file written: ../../database/PASCAL_format/SegmentationClass\169474254.png
# file written: ../../database/PASCAL_format/SegmentationClass\175484438.png
# file written: ../../database/PASCAL_format/SegmentationClass\175934755.png
# file written: ../../database/PASCAL_format/SegmentationClass\176329920.png
# file written: ../../database/PASCAL_format/SegmentationClass\176593348.png
# file written: ../../database/PASCAL_format/SegmentationClass\176593349.png
# file written: ../../database/PASCAL_format/SegmentationClass\176593350.png
# file written: ../../database/PASCAL_format/SegmentationClass\177075398.png
# file written: ../../database/PASCAL_format/SegmentationClass\179776749.png
# file written: ../../database/PASCAL_format/SegmentationClass\180332956.png
# file written: ../../database/PASCAL_format/SegmentationClass\180347405.png
# file written: ../../database/PASCAL_format/SegmentationClass\180348751.png
# file written: ../../database/PASCAL_format/SegmentationClass\180348757.png
# file written: ../../database/PASCAL_format/SegmentationClass\181684134.png
# file written: ../../database/PASCAL_format/SegmentationClass\182312368.png
# file written: ../../database/PASCAL_format/SegmentationClass\182894027.png
# file written: ../../database/PASCAL_format/SegmentationClass\182894050.png
# file written: ../../database/PASCAL_format/SegmentationClass\184330134.png
# file written: ../../database/PASCAL_format/SegmentationClass\186123785.png
# file written: ../../database/PASCAL_format/SegmentationClass\186758578.png
# file written: ../../database/PASCAL_format/SegmentationClass\186758588.png
# file written: ../../database/PASCAL_format/SegmentationClass\189673783.png
# file written: ../../database/PASCAL_format/SegmentationClass\191987952.png
# file written: ../../database/PASCAL_format/SegmentationClass\192926523.png
# file written: ../../database/PASCAL_format/SegmentationClass\194700833.png
# file written: ../../database/PASCAL_format/SegmentationClass\202645760.png
# file written: ../../database/PASCAL_format/SegmentationClass\202645761.png
# file written: ../../database/PASCAL_format/SegmentationClass\206196610.png
# file written: ../../database/PASCAL_format/SegmentationClass\206630543.png
# file written: ../../database/PASCAL_format/SegmentationClass\206631643.png
# file written: ../../database/PASCAL_format/SegmentationClass\206631857.png
# file written: ../../database/PASCAL_format/SegmentationClass\209897615.png
# file written: ../../database/PASCAL_format/SegmentationClass\209901592.png
# file written: ../../database/PASCAL_format/SegmentationClass\209901602.png
# file written: ../../database/PASCAL_format/SegmentationClass\209916716.png
# file written: ../../database/PASCAL_format/SegmentationClass\209916719.png
# file written: ../../database/PASCAL_format/SegmentationClass\211780685.png
# file written: ../../database/PASCAL_format/SegmentationClass\214376131.png
# file written: ../../database/PASCAL_format/SegmentationClass\217505807.png
# file written: ../../database/PASCAL_format/SegmentationClass\217680410.png
# file written: ../../database/PASCAL_format/SegmentationClass\219035790.png
# file written: ../../database/PASCAL_format/SegmentationClass\220772336.png
# file written: ../../database/PASCAL_format/SegmentationClass\221488777.png
# file written: ../../database/PASCAL_format/SegmentationClass\221515848.png
# file written: ../../database/PASCAL_format/SegmentationClass\224656352.png
# file written: ../../database/PASCAL_format/SegmentationClass\224659159.png
# file written: ../../database/PASCAL_format/SegmentationClass\224659301.png
# file written: ../../database/PASCAL_format/SegmentationClass\226141664.png
# file written: ../../database/PASCAL_format/SegmentationClass\226833218.png
# file written: ../../database/PASCAL_format/SegmentationClass\226833224.png
# file written: ../../database/PASCAL_format/SegmentationClass\229125509.png
# file written: ../../database/PASCAL_format/SegmentationClass\231771817.png
# file written: ../../database/PASCAL_format/SegmentationClass\23289018.png
# file written: ../../database/PASCAL_format/SegmentationClass\23289025.png
# file written: ../../database/PASCAL_format/SegmentationClass\23290936.png
# file written: ../../database/PASCAL_format/SegmentationClass\233333777.png
# file written: ../../database/PASCAL_format/SegmentationClass\23365820.png
# file written: ../../database/PASCAL_format/SegmentationClass\233913205.png
# file written: ../../database/PASCAL_format/SegmentationClass\234753663.png
# file written: ../../database/PASCAL_format/SegmentationClass\235506774.png
# file written: ../../database/PASCAL_format/SegmentationClass\235713309.png
# file written: ../../database/PASCAL_format/SegmentationClass\236399113.png
# file written: ../../database/PASCAL_format/SegmentationClass\23655368.png
# file written: ../../database/PASCAL_format/SegmentationClass\237054156.png
# file written: ../../database/PASCAL_format/SegmentationClass\238131051.png
# file written: ../../database/PASCAL_format/SegmentationClass\24706432.png
# file written: ../../database/PASCAL_format/SegmentationClass\24833427.png
# file written: ../../database/PASCAL_format/SegmentationClass\251092860.png
# file written: ../../database/PASCAL_format/SegmentationClass\251110755.png
# file written: ../../database/PASCAL_format/SegmentationClass\251382210.png
# file written: ../../database/PASCAL_format/SegmentationClass\255160448.png
# file written: ../../database/PASCAL_format/SegmentationClass\255267686.png
# file written: ../../database/PASCAL_format/SegmentationClass\255462084.png
# file written: ../../database/PASCAL_format/SegmentationClass\255462087.png
# file written: ../../database/PASCAL_format/SegmentationClass\255477273.png
# file written: ../../database/PASCAL_format/SegmentationClass\255487584.png
# file written: ../../database/PASCAL_format/SegmentationClass\256728299.png
# file written: ../../database/PASCAL_format/SegmentationClass\256850935.png
# file written: ../../database/PASCAL_format/SegmentationClass\256850936.png
# file written: ../../database/PASCAL_format/SegmentationClass\256850939.png
# file written: ../../database/PASCAL_format/SegmentationClass\257519463.png
# file written: ../../database/PASCAL_format/SegmentationClass\257800584.png
# file written: ../../database/PASCAL_format/SegmentationClass\258998102.png
# file written: ../../database/PASCAL_format/SegmentationClass\259601056.png
# file written: ../../database/PASCAL_format/SegmentationClass\259651363.png
# file written: ../../database/PASCAL_format/SegmentationClass\259651368.png
# file written: ../../database/PASCAL_format/SegmentationClass\259656738.png
# file written: ../../database/PASCAL_format/SegmentationClass\261564557.png
# file written: ../../database/PASCAL_format/SegmentationClass\264160545.png
# file written: ../../database/PASCAL_format/SegmentationClass\264843162.png
# file written: ../../database/PASCAL_format/SegmentationClass\264843169.png
# file written: ../../database/PASCAL_format/SegmentationClass\265891023.png
# file written: ../../database/PASCAL_format/SegmentationClass\27081537.png
# file written: ../../database/PASCAL_format/SegmentationClass\27094261.png
# file written: ../../database/PASCAL_format/SegmentationClass\27099913.png
# file written: ../../database/PASCAL_format/SegmentationClass\27292693.png
# file written: ../../database/PASCAL_format/SegmentationClass\274716780.png
# file written: ../../database/PASCAL_format/SegmentationClass\277994505.png
# file written: ../../database/PASCAL_format/SegmentationClass\278577443.png
# file written: ../../database/PASCAL_format/SegmentationClass\279671257.png
# file written: ../../database/PASCAL_format/SegmentationClass\280005915.png
# file written: ../../database/PASCAL_format/SegmentationClass\283478016.png
# file written: ../../database/PASCAL_format/SegmentationClass\284469844.png
# file written: ../../database/PASCAL_format/SegmentationClass\28459161.png
# file written: ../../database/PASCAL_format/SegmentationClass\28460666.png
# file written: ../../database/PASCAL_format/SegmentationClass\285596127.png
# file written: ../../database/PASCAL_format/SegmentationClass\28815732.png
# file written: ../../database/PASCAL_format/SegmentationClass\288728572.png
# file written: ../../database/PASCAL_format/SegmentationClass\288859978.png
# file written: ../../database/PASCAL_format/SegmentationClass\28920464.png
# file written: ../../database/PASCAL_format/SegmentationClass\28920487.png
# file written: ../../database/PASCAL_format/SegmentationClass\290269292.png
# file written: ../../database/PASCAL_format/SegmentationClass\290273167.png
# file written: ../../database/PASCAL_format/SegmentationClass\290273169.png
# file written: ../../database/PASCAL_format/SegmentationClass\292630167.png
# file written: ../../database/PASCAL_format/SegmentationClass\301709163.png
# file written: ../../database/PASCAL_format/SegmentationClass\303813581.png
# file written: ../../database/PASCAL_format/SegmentationClass\304720518.png
# file written: ../../database/PASCAL_format/SegmentationClass\30528265.png
# file written: ../../database/PASCAL_format/SegmentationClass\305715072.png
# file written: ../../database/PASCAL_format/SegmentationClass\306739286.png
# file written: ../../database/PASCAL_format/SegmentationClass\30794557.png
# file written: ../../database/PASCAL_format/SegmentationClass\307972637.png
# file written: ../../database/PASCAL_format/SegmentationClass\308307120.png
# file written: ../../database/PASCAL_format/SegmentationClass\308307124.png
# file written: ../../database/PASCAL_format/SegmentationClass\309309707.png
# file written: ../../database/PASCAL_format/SegmentationClass\309309709.png
# file written: ../../database/PASCAL_format/SegmentationClass\310661315.png
# file written: ../../database/PASCAL_format/SegmentationClass\312841186.png
# file written: ../../database/PASCAL_format/SegmentationClass\313031581.png
# file written: ../../database/PASCAL_format/SegmentationClass\313032023.png
# file written: ../../database/PASCAL_format/SegmentationClass\313032753.png
# file written: ../../database/PASCAL_format/SegmentationClass\313032759.png
# file written: ../../database/PASCAL_format/SegmentationClass\313032760.png
# file written: ../../database/PASCAL_format/SegmentationClass\31374648.png
# file written: ../../database/PASCAL_format/SegmentationClass\31374858.png
# file written: ../../database/PASCAL_format/SegmentationClass\314623049.png
# file written: ../../database/PASCAL_format/SegmentationClass\314623066.png
# file written: ../../database/PASCAL_format/SegmentationClass\314624239.png
# file written: ../../database/PASCAL_format/SegmentationClass\315685509.png
# file written: ../../database/PASCAL_format/SegmentationClass\317531114.png
# file written: ../../database/PASCAL_format/SegmentationClass\317614423.png
# file written: ../../database/PASCAL_format/SegmentationClass\317614424.png
# file written: ../../database/PASCAL_format/SegmentationClass\317614426.png
# file written: ../../database/PASCAL_format/SegmentationClass\31778898.png
# file written: ../../database/PASCAL_format/SegmentationClass\317871598.png
# file written: ../../database/PASCAL_format/SegmentationClass\319341287.png
# file written: ../../database/PASCAL_format/SegmentationClass\319926728.png
# file written: ../../database/PASCAL_format/SegmentationClass\321568625.png
# file written: ../../database/PASCAL_format/SegmentationClass\321574057.png
# file written: ../../database/PASCAL_format/SegmentationClass\322784130.png
# file written: ../../database/PASCAL_format/SegmentationClass\32459578.png
# file written: ../../database/PASCAL_format/SegmentationClass\327172084.png
# file written: ../../database/PASCAL_format/SegmentationClass\328839921.png
# file written: ../../database/PASCAL_format/SegmentationClass\333080879.png
# file written: ../../database/PASCAL_format/SegmentationClass\333080881.png
# file written: ../../database/PASCAL_format/SegmentationClass\33583159.png
# file written: ../../database/PASCAL_format/SegmentationClass\339831633.png
# file written: ../../database/PASCAL_format/SegmentationClass\339841242.png
# file written: ../../database/PASCAL_format/SegmentationClass\341600327.png
# file written: ../../database/PASCAL_format/SegmentationClass\343224426.png
# file written: ../../database/PASCAL_format/SegmentationClass\34581464.png
# file written: ../../database/PASCAL_format/SegmentationClass\346398833.png
# file written: ../../database/PASCAL_format/SegmentationClass\351595796.png
# file written: ../../database/PASCAL_format/SegmentationClass\357530131.png
# file written: ../../database/PASCAL_format/SegmentationClass\363025783.png
# file written: ../../database/PASCAL_format/SegmentationClass\363821145.png
# file written: ../../database/PASCAL_format/SegmentationClass\363821164.png
# file written: ../../database/PASCAL_format/SegmentationClass\363847343.png
# file written: ../../database/PASCAL_format/SegmentationClass\363855966.png
# file written: ../../database/PASCAL_format/SegmentationClass\363855967.png
# file written: ../../database/PASCAL_format/SegmentationClass\363855968.png
# file written: ../../database/PASCAL_format/SegmentationClass\363855973.png
# file written: ../../database/PASCAL_format/SegmentationClass\363855978.png
# file written: ../../database/PASCAL_format/SegmentationClass\363855980.png
# file written: ../../database/PASCAL_format/SegmentationClass\364021590.png
# file written: ../../database/PASCAL_format/SegmentationClass\364021593.png
# file written: ../../database/PASCAL_format/SegmentationClass\364021594.png
# file written: ../../database/PASCAL_format/SegmentationClass\364021598.png
# file written: ../../database/PASCAL_format/SegmentationClass\364021639.png
# file written: ../../database/PASCAL_format/SegmentationClass\364021645.png
# file written: ../../database/PASCAL_format/SegmentationClass\364023375.png
# file written: ../../database/PASCAL_format/SegmentationClass\364837568.png
# file written: ../../database/PASCAL_format/SegmentationClass\365004779.png
# file written: ../../database/PASCAL_format/SegmentationClass\366446718.png
# file written: ../../database/PASCAL_format/SegmentationClass\368044156.png
# file written: ../../database/PASCAL_format/SegmentationClass\371660154.png
# file written: ../../database/PASCAL_format/SegmentationClass\371751497.png
# file written: ../../database/PASCAL_format/SegmentationClass\373229508.png
# file written: ../../database/PASCAL_format/SegmentationClass\374425437.png
# file written: ../../database/PASCAL_format/SegmentationClass\377543476.png
# file written: ../../database/PASCAL_format/SegmentationClass\377644879.png
# file written: ../../database/PASCAL_format/SegmentationClass\378149475.png
# file written: ../../database/PASCAL_format/SegmentationClass\386912747.png
# file written: ../../database/PASCAL_format/SegmentationClass\388772955.png
# file written: ../../database/PASCAL_format/SegmentationClass\391794430.png
# file written: ../../database/PASCAL_format/SegmentationClass\391794433.png
# file written: ../../database/PASCAL_format/SegmentationClass\393694776.png
# file written: ../../database/PASCAL_format/SegmentationClass\395031252.png
# file written: ../../database/PASCAL_format/SegmentationClass\395308824.png
# file written: ../../database/PASCAL_format/SegmentationClass\395308834.png
# file written: ../../database/PASCAL_format/SegmentationClass\399001272.png
# file written: ../../database/PASCAL_format/SegmentationClass\399001279.png
# file written: ../../database/PASCAL_format/SegmentationClass\401889261.png
# file written: ../../database/PASCAL_format/SegmentationClass\402492112.png
# file written: ../../database/PASCAL_format/SegmentationClass\402792787.png
# file written: ../../database/PASCAL_format/SegmentationClass\402929261.png
# file written: ../../database/PASCAL_format/SegmentationClass\402929767.png
# file written: ../../database/PASCAL_format/SegmentationClass\404475993.png
# file written: ../../database/PASCAL_format/SegmentationClass\405051029.png
# file written: ../../database/PASCAL_format/SegmentationClass\405874587.png
# file written: ../../database/PASCAL_format/SegmentationClass\405875567.png
# file written: ../../database/PASCAL_format/SegmentationClass\406874352.png
# file written: ../../database/PASCAL_format/SegmentationClass\407269205.png
# file written: ../../database/PASCAL_format/SegmentationClass\40784943.png
# file written: ../../database/PASCAL_format/SegmentationClass\409100585.png
# file written: ../../database/PASCAL_format/SegmentationClass\411212356.png
# file written: ../../database/PASCAL_format/SegmentationClass\412178612.png
# file written: ../../database/PASCAL_format/SegmentationClass\41363165.png
# file written: ../../database/PASCAL_format/SegmentationClass\417133000.png
# file written: ../../database/PASCAL_format/SegmentationClass\418126155.png
# file written: ../../database/PASCAL_format/SegmentationClass\418127019.png
# file written: ../../database/PASCAL_format/SegmentationClass\418297194.png
# file written: ../../database/PASCAL_format/SegmentationClass\41874619.png
# file written: ../../database/PASCAL_format/SegmentationClass\419967624.png
# file written: ../../database/PASCAL_format/SegmentationClass\422371150.png
# file written: ../../database/PASCAL_format/SegmentationClass\423908331.png
# file written: ../../database/PASCAL_format/SegmentationClass\425214705.png
# file written: ../../database/PASCAL_format/SegmentationClass\426441769.png
# file written: ../../database/PASCAL_format/SegmentationClass\426609126.png
# file written: ../../database/PASCAL_format/SegmentationClass\427489763.png
# file written: ../../database/PASCAL_format/SegmentationClass\429780092.png
# file written: ../../database/PASCAL_format/SegmentationClass\43035578.png
# file written: ../../database/PASCAL_format/SegmentationClass\43055418.png
# file written: ../../database/PASCAL_format/SegmentationClass\43055800.png
# file written: ../../database/PASCAL_format/SegmentationClass\431481498.png
# file written: ../../database/PASCAL_format/SegmentationClass\432343792.png
# file written: ../../database/PASCAL_format/SegmentationClass\433133816.png
# file written: ../../database/PASCAL_format/SegmentationClass\433133817.png
# file written: ../../database/PASCAL_format/SegmentationClass\433317364.png
# file written: ../../database/PASCAL_format/SegmentationClass\43482079.png
# file written: ../../database/PASCAL_format/SegmentationClass\434901397.png
# file written: ../../database/PASCAL_format/SegmentationClass\436198487.png
# file written: ../../database/PASCAL_format/SegmentationClass\43666752.png
# file written: ../../database/PASCAL_format/SegmentationClass\440425951.png
# file written: ../../database/PASCAL_format/SegmentationClass\441866281.png
# file written: ../../database/PASCAL_format/SegmentationClass\444319214.png
# file written: ../../database/PASCAL_format/SegmentationClass\444933584.png
# file written: ../../database/PASCAL_format/SegmentationClass\446037955.png
# file written: ../../database/PASCAL_format/SegmentationClass\44634948.png
# file written: ../../database/PASCAL_format/SegmentationClass\44635188.png
# file written: ../../database/PASCAL_format/SegmentationClass\44635204.png
# file written: ../../database/PASCAL_format/SegmentationClass\446898797.png
# file written: ../../database/PASCAL_format/SegmentationClass\447327113.png
# file written: ../../database/PASCAL_format/SegmentationClass\447781482.png
# file written: ../../database/PASCAL_format/SegmentationClass\448329578.png
# file written: ../../database/PASCAL_format/SegmentationClass\44885336.png
# file written: ../../database/PASCAL_format/SegmentationClass\44896148.png
# file written: ../../database/PASCAL_format/SegmentationClass\452710630.png
# file written: ../../database/PASCAL_format/SegmentationClass\455411217.png
# file written: ../../database/PASCAL_format/SegmentationClass\456841043.png
# file written: ../../database/PASCAL_format/SegmentationClass\456884384.png
# file written: ../../database/PASCAL_format/SegmentationClass\457353772.png
# file written: ../../database/PASCAL_format/SegmentationClass\458810893.png
# file written: ../../database/PASCAL_format/SegmentationClass\458810898.png
# file written: ../../database/PASCAL_format/SegmentationClass\460830572.png
# file written: ../../database/PASCAL_format/SegmentationClass\461017732.png
# file written: ../../database/PASCAL_format/SegmentationClass\461017733.png
# file written: ../../database/PASCAL_format/SegmentationClass\461017734.png
# file written: ../../database/PASCAL_format/SegmentationClass\461017735.png
# file written: ../../database/PASCAL_format/SegmentationClass\461017736.png
# file written: ../../database/PASCAL_format/SegmentationClass\467670221.png
# file written: ../../database/PASCAL_format/SegmentationClass\468517244.png
# file written: ../../database/PASCAL_format/SegmentationClass\468787720.png
# file written: ../../database/PASCAL_format/SegmentationClass\468921229.png
# file written: ../../database/PASCAL_format/SegmentationClass\469222453.png
# file written: ../../database/PASCAL_format/SegmentationClass\469278707.png
# file written: ../../database/PASCAL_format/SegmentationClass\470310711.png
# file written: ../../database/PASCAL_format/SegmentationClass\470413148.png
# file written: ../../database/PASCAL_format/SegmentationClass\470707782.png
# file written: ../../database/PASCAL_format/SegmentationClass\471844220.png
# file written: ../../database/PASCAL_format/SegmentationClass\471969044.png
# file written: ../../database/PASCAL_format/SegmentationClass\472218412.png
# file written: ../../database/PASCAL_format/SegmentationClass\476190974.png
# file written: ../../database/PASCAL_format/SegmentationClass\480480976.png
# file written: ../../database/PASCAL_format/SegmentationClass\481674231.png
# file written: ../../database/PASCAL_format/SegmentationClass\481698999.png
# file written: ../../database/PASCAL_format/SegmentationClass\491147902.png
# file written: ../../database/PASCAL_format/SegmentationClass\492117055.png
# file written: ../../database/PASCAL_format/SegmentationClass\493535535.png
# file written: ../../database/PASCAL_format/SegmentationClass\494958227.png
# file written: ../../database/PASCAL_format/SegmentationClass\495269744.png
# file written: ../../database/PASCAL_format/SegmentationClass\495926981.png
# file written: ../../database/PASCAL_format/SegmentationClass\495972899.png
# file written: ../../database/PASCAL_format/SegmentationClass\495972968.png
# file written: ../../database/PASCAL_format/SegmentationClass\496132130.png
# file written: ../../database/PASCAL_format/SegmentationClass\503570914.png
# file written: ../../database/PASCAL_format/SegmentationClass\50508304.png
# file written: ../../database/PASCAL_format/SegmentationClass\50508378.png
# file written: ../../database/PASCAL_format/SegmentationClass\50508483.png
# file written: ../../database/PASCAL_format/SegmentationClass\508588206.png
# file written: ../../database/PASCAL_format/SegmentationClass\508588207.png
# file written: ../../database/PASCAL_format/SegmentationClass\508801197.png
# file written: ../../database/PASCAL_format/SegmentationClass\509665245.png
# file written: ../../database/PASCAL_format/SegmentationClass\513706021.png
# file written: ../../database/PASCAL_format/SegmentationClass\515098952.png
# file written: ../../database/PASCAL_format/SegmentationClass\518296717.png
# file written: ../../database/PASCAL_format/SegmentationClass\518398476.png
# file written: ../../database/PASCAL_format/SegmentationClass\52203064.png
# file written: ../../database/PASCAL_format/SegmentationClass\528940288.png
# file written: ../../database/PASCAL_format/SegmentationClass\531053172.png
# file written: ../../database/PASCAL_format/SegmentationClass\534389190.png
# file written: ../../database/PASCAL_format/SegmentationClass\539427166.png
# file written: ../../database/PASCAL_format/SegmentationClass\54060006.png
# file written: ../../database/PASCAL_format/SegmentationClass\54278401.png
# file written: ../../database/PASCAL_format/SegmentationClass\544168893.png
# file written: ../../database/PASCAL_format/SegmentationClass\54443512.png
# file written: ../../database/PASCAL_format/SegmentationClass\546361665.png
# file written: ../../database/PASCAL_format/SegmentationClass\546361667.png
# file written: ../../database/PASCAL_format/SegmentationClass\546924098.png
# file written: ../../database/PASCAL_format/SegmentationClass\546943598.png
# file written: ../../database/PASCAL_format/SegmentationClass\548420990.png
# file written: ../../database/PASCAL_format/SegmentationClass\54884689.png
# file written: ../../database/PASCAL_format/SegmentationClass\549411950.png
# file written: ../../database/PASCAL_format/SegmentationClass\551331553.png
# file written: ../../database/PASCAL_format/SegmentationClass\556607139.png
# file written: ../../database/PASCAL_format/SegmentationClass\557143501.png
# file written: ../../database/PASCAL_format/SegmentationClass\557334727.png
# file written: ../../database/PASCAL_format/SegmentationClass\55848090.png
# file written: ../../database/PASCAL_format/SegmentationClass\559370774.png
# file written: ../../database/PASCAL_format/SegmentationClass\564127049.png
# file written: ../../database/PASCAL_format/SegmentationClass\56463099.png
# file written: ../../database/PASCAL_format/SegmentationClass\56844815.png
# file written: ../../database/PASCAL_format/SegmentationClass\56844876.png
# file written: ../../database/PASCAL_format/SegmentationClass\570594317.png
# file written: ../../database/PASCAL_format/SegmentationClass\572187256.png
# file written: ../../database/PASCAL_format/SegmentationClass\576848806.png
# file written: ../../database/PASCAL_format/SegmentationClass\586437980.png
# file written: ../../database/PASCAL_format/SegmentationClass\588693269.png
# file written: ../../database/PASCAL_format/SegmentationClass\588719541.png
# file written: ../../database/PASCAL_format/SegmentationClass\588786395.png
# file written: ../../database/PASCAL_format/SegmentationClass\70872439.png
# file written: ../../database/PASCAL_format/SegmentationClass\72370074.png
# file written: ../../database/PASCAL_format/SegmentationClass\75497667.png
# file written: ../../database/PASCAL_format/SegmentationClass\79875403.png
# file written: ../../database/PASCAL_format/SegmentationClass\80033918.png
# file written: ../../database/PASCAL_format/SegmentationClass\88187333.png
# file written: ../../database/PASCAL_format/SegmentationClass\95551586.png
# file written: ../../database/PASCAL_format/SegmentationClass\322951795.png
# file written: ../../database/PASCAL_format/SegmentationClass\341043279.png
# file written: ../../database/PASCAL_format/SegmentationClass\379442285.png
# file written: ../../database/PASCAL_format/SegmentationClass\401997488.png
# file written: ../../database/PASCAL_format/SegmentationClass\412178615.png
