# %%
import os

image_root_path = "../../database/training"
new_image_root_path = "../../database/PASCAL_format/JPEGImages"
root_path = '../../database/PASCAL_format/SegmentationClass'

def GetLista(path):
    global image_root_path
    image_root_path = path
    lista = [f.replace(".json","") for f in os.listdir(image_root_path) if f.endswith(".json")]
    return lista

# %%
import  os
if not os.path.exists(root_path):
    os.makedirs(root_path)

# %%
import os
from lxml import etree
import json
import cv2
import numpy as np

def GenerateFile(file, image_root_path):
    _json_path = os.path.join(image_root_path,file+'.json')
    with open(_json_path, 'r') as f:
        read_data = f.read()
    _data = json.loads(read_data)
    _shapes = [shape["points"] for shape in _data["shapes"] if shape["label"]=="1"]
    
    filename = file + ".png"
    file_path = os.path.join(root_path, filename)
    if(os.path.isfile(file_path)):
        os.remove(file_path)
    
    _image_path = os.path.join(new_image_root_path,file+'.jpg')
    _img = cv2.imread(_image_path, 1)
    
    _mask = np.zeros((_img.shape[0], _img.shape[1]))
    for _shape in _shapes:
        _shape.append(_shape[0])
        _shape = [[int(round(pt[0], 0)), int(round(pt[1], 0))] for pt in _shape]
        _pts=np.array(_shape)
        _roi_pts = _pts.reshape((-1, 1, 2))
        cv2.fillConvexPoly(_mask, _roi_pts, 1)
        
    _mask = _mask.astype(np.bool)  
    out = np.zeros_like(_img)
    out[_mask] = 255
    cv2.imwrite(file_path, out)

    print("file written:", file_path)
    
lista=GetLista("../../database/training")
for f in lista:
    GenerateFile(f, image_root_path)
    
lista=GetLista("../../database/testing")
for f in lista:
    GenerateFile(f, image_root_path)
# Out:
# file written: ../SegmentationClass\132613254.png
# file written: ../SegmentationClass\137007454.png
# file written: ../SegmentationClass\137007455.png
# file written: ../SegmentationClass\157756975.png
# file written: ../SegmentationClass\157967280.png
# file written: ../SegmentationClass\158768955.png
# file written: ../SegmentationClass\158974988.png
# file written: ../SegmentationClass\159269575.png
# file written: ../SegmentationClass\175934755.png
# file written: ../SegmentationClass\180347405.png
# file written: ../SegmentationClass\182312368.png
# file written: ../SegmentationClass\186758578.png
# file written: ../SegmentationClass\186758588.png
# file written: ../SegmentationClass\192926523.png
# file written: ../SegmentationClass\226141664.png
# file written: ../SegmentationClass\23289018.png
# file written: ../SegmentationClass\23289025.png
# file written: ../SegmentationClass\23365820.png
# file written: ../SegmentationClass\235506774.png
# file written: ../SegmentationClass\255462087.png
# file written: ../SegmentationClass\256850935.png
# file written: ../SegmentationClass\256850936.png
# file written: ../SegmentationClass\256850939.png
# file written: ../SegmentationClass\257519463.png
# file written: ../SegmentationClass\274716780.png
# file written: ../SegmentationClass\278577443.png
# file written: ../SegmentationClass\28815732.png
# file written: ../SegmentationClass\305715072.png
# file written: ../SegmentationClass\32459578.png
# file written: ../SegmentationClass\328839921.png
# file written: ../SegmentationClass\363025783.png
# file written: ../SegmentationClass\363821145.png
# file written: ../SegmentationClass\363847343.png
# file written: ../SegmentationClass\364021593.png
# file written: ../SegmentationClass\364021594.png
# file written: ../SegmentationClass\364021598.png
# file written: ../SegmentationClass\364021639.png
# file written: ../SegmentationClass\364021645.png
# file written: ../SegmentationClass\364023375.png
# file written: ../SegmentationClass\374425437.png
# file written: ../SegmentationClass\395308824.png
# file written: ../SegmentationClass\395308834.png
# file written: ../SegmentationClass\41874619.png
# file written: ../SegmentationClass\425214705.png
# file written: ../SegmentationClass\426609126.png
# file written: ../SegmentationClass\429780092.png
# file written: ../SegmentationClass\44896148.png
# file written: ../SegmentationClass\52203064.png
# file written: ../SegmentationClass\546361667.png
# file written: ../SegmentationClass\551331553.png
# file written: ../SegmentationClass\559370774.png
